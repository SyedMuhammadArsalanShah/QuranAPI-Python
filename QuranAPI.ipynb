# %% [markdown]
# ### Quran API - PYTHON

# %% [markdown]
# ## install packages

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\mypc\pycharmprojects\pythonproject5\.venv\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mypc\pycharmprojects\pythonproject5\.venv\lib\site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mypc\pycharmprojects\pythonproject5\.venv\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mypc\pycharmprojects\pythonproject5\.venv\lib\site-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mypc\pycharmprojects\pythonproject5\.venv\lib\site-packages (from requests) (2025.4.26)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install playsound==1.2.2
# Out:
# Requirement already satisfied: playsound==1.2.2 in c:\users\mypc\pycharmprojects\pythonproject5\.venv\lib\site-packages (1.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
import json
import os
from playsound import playsound

BASE_URL="https://api.alquran.cloud/v1/"

# %% [markdown]
# ### Function to list all Surahs

# %%
def list_surah():
    response =requests.get(f"{BASE_URL}/surah")
    if response.status_code==200:
        surahs= response.json()["data"]
        for surah in surahs:
            print(f"{surah["number"]} | { surah["name"]} | {surah["numberOfAyahs"]} ")
    else: 
        print("fetching error in api")
# list_surah()
# Out:
# 1 | سُورَةُ ٱلْفَاتِحَةِ | 7
# 2 | سُورَةُ البَقَرَةِ | 286
# 3 | سُورَةُ آلِ عِمۡرَانَ | 200
# 4 | سُورَةُ النِّسَاءِ | 176
# 5 | سُورَةُ المَائـِدَةِ | 120
# 6 | سُورَةُ الأَنۡعَامِ | 165
# 7 | سُورَةُ الأَعۡرَافِ | 206
# 8 | سُورَةُ الأَنفَالِ | 75
# 9 | سُورَةُ التَّوۡبَةِ | 129
# 10 | سُورَةُ يُونُسَ | 109
# 11 | سُورَةُ هُودٍ | 123
# 12 | سُورَةُ يُوسُفَ | 111
# 13 | سُورَةُ الرَّعۡدِ | 43
# 14 | سُورَةُ إِبۡرَاهِيمَ | 52
# 15 | سُورَةُ الحِجۡرِ | 99
# 16 | سُورَةُ النَّحۡلِ | 128
# 17 | سُورَةُ الإِسۡرَاءِ | 111
# 18 | سُورَةُ الكَهۡفِ | 110
# 19 | سُورَةُ مَرۡيَمَ | 98
# 20 | سُورَةُ طه | 135
# 21 | سُورَةُ الأَنبِيَاءِ | 112
# 22 | سُورَةُ الحَجِّ | 78
# 23 | سُورَةُ المُؤۡمِنُونَ | 118
# 24 | سُورَةُ النُّورِ | 64
# 25 | سُورَةُ الفُرۡقَانِ | 77
# 26 | سُورَةُ الشُّعَرَاءِ | 227
# 27 | سُورَةُ النَّمۡلِ | 93
# 28 | سُورَةُ القَصَصِ | 88
# 29 | سُورَةُ العَنكَبُوتِ | 69
# 30 | سُورَةُ الرُّومِ | 60
# 31 | سُورَةُ لُقۡمَانَ | 34
# 32 | سُورَةُ السَّجۡدَةِ | 30
# 33 | سُورَةُ الأَحۡزَابِ | 73
# 34 | سُورَةُ سَبَإٍ | 54
# 35 | سُورَةُ فَاطِرٍ | 45
# 36 | سُورَةُ يسٓ | 83
# 37 | سُورَةُ الصَّافَّاتِ | 182
# 38 | سُورَةُ صٓ | 88
# 39 | سُورَةُ الزُّمَرِ | 75
# 40 | سُورَةُ غَافِرٍ | 85
# 41 | سُورَةُ فُصِّلَتۡ | 54
# 42 | سُورَةُ الشُّورَىٰ | 53
# 43 | سُورَةُ الزُّخۡرُفِ | 89
# 44 | سُورَةُ الدُّخَانِ | 59
# 45 | سُورَةُ الجَاثِيَةِ | 37
# 46 | سُورَةُ الأَحۡقَافِ | 35
# 47 | سُورَةُ مُحَمَّدٍ | 38
# 48 | سُورَةُ الفَتۡحِ | 29
# 49 | سُورَةُ الحُجُرَاتِ | 18
# 50 | سُورَةُ قٓ | 45
# 51 | سُورَةُ الذَّارِيَاتِ | 60
# 52 | سُورَةُ الطُّورِ | 49
# 53 | سُورَةُ النَّجۡمِ | 62
# 54 | سُورَةُ القَمَرِ | 55
# 55 | سُورَةُ الرَّحۡمَٰن | 78
# 56 | سُورَةُ الوَاقِعَةِ | 96
# 57 | سُورَةُ الحَدِيدِ | 29
# 58 | سُورَةُ المُجَادلَةِ | 22
# 59 | سُورَةُ الحَشۡرِ | 24
# 60 | سُورَةُ المُمۡتَحنَةِ | 13
# 61 | سُورَةُ الصَّفِّ | 14
# 62 | سُورَةُ الجُمُعَةِ | 11
# 63 | سُورَةُ المُنَافِقُونَ | 11
# 64 | سُورَةُ التَّغَابُنِ | 18
# 65 | سُورَةُ الطَّلَاقِ | 12
# 66 | سُورَةُ التَّحۡرِيمِ | 12
# 67 | سُورَةُ المُلۡكِ | 30
# 68 | سُورَةُ القَلَمِ | 52
# 69 | سُورَةُ الحَاقَّةِ | 52
# 70 | سُورَةُ المَعَارِجِ | 44
# 71 | سُورَةُ نُوحٍ | 28
# 72 | سُورَةُ الجِنِّ | 28
# 73 | سُورَةُ المُزَّمِّلِ | 20
# 74 | سُورَةُ المُدَّثِّرِ | 56
# 75 | سُورَةُ القِيَامَةِ | 40
# 76 | سُورَةُ الإِنسَانِ | 31
# 77 | سُورَةُ المُرۡسَلَاتِ | 50
# 78 | سُورَةُ النَّبَإِ | 40
# 79 | سُورَةُ النَّازِعَاتِ | 46
# 80 | سُورَةُ عَبَسَ | 42
# 81 | سُورَةُ التَّكۡوِيرِ | 29
# 82 | سُورَةُ الانفِطَارِ | 19
# 83 | سُورَةُ المُطَفِّفِينَ | 36
# 84 | سُورَةُ الانشِقَاقِ | 25
# 85 | سُورَةُ البُرُوجِ | 22
# 86 | سُورَةُ الطَّارِقِ | 17
# 87 | سُورَةُ الأَعۡلَىٰ | 19
# 88 | سُورَةُ الغَاشِيَةِ | 26
# 89 | سُورَةُ الفَجۡرِ | 30
# 90 | سُورَةُ البَلَدِ | 20
# 91 | سُورَةُ الشَّمۡسِ | 15
# 92 | سُورَةُ اللَّيۡلِ | 21
# 93 | سُورَةُ الضُّحَىٰ | 11
# 94 | سُورَةُ الشَّرۡحِ | 8
# 95 | سُورَةُ التِّينِ | 8
# 96 | سُورَةُ العَلَقِ | 19
# 97 | سُورَةُ القَدۡرِ | 5
# 98 | سُورَةُ البَيِّنَةِ | 8
# 99 | سُورَةُ الزَّلۡزَلَةِ | 8
# 100 | سُورَةُ العَادِيَاتِ | 11
# 101 | سُورَةُ القَارِعَةِ | 11
# 102 | سُورَةُ التَّكَاثُرِ | 8
# 103 | سُورَةُ العَصۡرِ | 3
# 104 | سُورَةُ الهُمَزَةِ | 9
# 105 | سُورَةُ الفِيلِ | 5
# 106 | سُورَةُ قُرَيۡشٍ | 4
# 107 | سُورَةُ المَاعُونِ | 7
# 108 | سُورَةُ الكَوۡثَرِ | 3
# 109 | سُورَةُ الكَافِرُونَ | 6
# 110 | سُورَةُ النَّصۡرِ | 3
# 111 | سُورَةُ المَسَدِ | 5
# 112 | سُورَةُ الإِخۡلَاصِ | 4
# 113 | سُورَةُ الفَلَقِ | 5
# 114 | سُورَةُ النَّاسِ | 6

# %% [markdown]
# ### Function to get Ayahs from a specific Surah

# %%
def get_surah(surah_number):
    response = requests.get(f"{BASE_URL}/surah/{surah_number}")
    if response.status_code == 200:
        ayahs = response.json()['data']['ayahs']
        for ayah in ayahs:
            print(f"{ayah['numberInSurah']}. {ayah['text']}")
    else:
        print("Invalid Surah number or API error.")
# get_surah(55)
# Out:
# 1. بِسۡمِ ٱللَّهِ ٱلرَّحۡمَـٰنِ ٱلرَّحِیمِ ٱلرَّحۡمَـٰنُ
#
# 2. عَلَّمَ ٱلۡقُرۡءَانَ
#
# 3. خَلَقَ ٱلۡإِنسَـٰنَ
#
# 4. عَلَّمَهُ ٱلۡبَیَانَ
#
# 5. ٱلشَّمۡسُ وَٱلۡقَمَرُ بِحُسۡبَانࣲ
#
# 6. وَٱلنَّجۡمُ وَٱلشَّجَرُ یَسۡجُدَانِ
#
# 7. وَٱلسَّمَاۤءَ رَفَعَهَا وَوَضَعَ ٱلۡمِیزَانَ
#
# 8. أَلَّا تَطۡغَوۡا۟ فِی ٱلۡمِیزَانِ
#
# 9. وَأَقِیمُوا۟ ٱلۡوَزۡنَ بِٱلۡقِسۡطِ وَلَا تُخۡسِرُوا۟ ٱلۡمِیزَانَ
#
# 10. وَٱلۡأَرۡضَ وَضَعَهَا لِلۡأَنَامِ
#
# 11. فِیهَا فَـٰكِهَةࣱ وَٱلنَّخۡلُ ذَاتُ ٱلۡأَكۡمَامِ
#
# 12. وَٱلۡحَبُّ ذُو ٱلۡعَصۡفِ وَٱلرَّیۡحَانُ
#
# 13. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 14. خَلَقَ ٱلۡإِنسَـٰنَ مِن صَلۡصَـٰلࣲ كَٱلۡفَخَّارِ
#
# 15. وَخَلَقَ ٱلۡجَاۤنَّ مِن مَّارِجࣲ مِّن نَّارࣲ
#
# 16. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 17. رَبُّ ٱلۡمَشۡرِقَیۡنِ وَرَبُّ ٱلۡمَغۡرِبَیۡنِ
#
# 18. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 19. مَرَجَ ٱلۡبَحۡرَیۡنِ یَلۡتَقِیَانِ
#
# 20. بَیۡنَهُمَا بَرۡزَخࣱ لَّا یَبۡغِیَانِ
#
# 21. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 22. یَخۡرُجُ مِنۡهُمَا ٱللُّؤۡلُؤُ وَٱلۡمَرۡجَانُ
#
# 23. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 24. وَلَهُ ٱلۡجَوَارِ ٱلۡمُنشَـَٔاتُ فِی ٱلۡبَحۡرِ كَٱلۡأَعۡلَـٰمِ
#
# 25. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 26. كُلُّ مَنۡ عَلَیۡهَا فَانࣲ
#
# 27. وَیَبۡقَىٰ وَجۡهُ رَبِّكَ ذُو ٱلۡجَلَـٰلِ وَٱلۡإِكۡرَامِ
#
# 28. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 29. یَسۡـَٔلُهُۥ مَن فِی ٱلسَّمَـٰوَ ٰ⁠تِ وَٱلۡأَرۡضِۚ كُلَّ یَوۡمٍ هُوَ فِی شَأۡنࣲ
#
# 30. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 31. سَنَفۡرُغُ لَكُمۡ أَیُّهَ ٱلثَّقَلَانِ
#
# 32. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 33. یَـٰمَعۡشَرَ ٱلۡجِنِّ وَٱلۡإِنسِ إِنِ ٱسۡتَطَعۡتُمۡ أَن تَنفُذُوا۟ مِنۡ أَقۡطَارِ ٱلسَّمَـٰوَ ٰ⁠تِ وَٱلۡأَرۡضِ فَٱنفُذُوا۟ۚ لَا تَنفُذُونَ إِلَّا بِسُلۡطَـٰنࣲ
#
# 34. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 35. یُرۡسَلُ عَلَیۡكُمَا شُوَاظࣱ مِّن نَّارࣲ وَنُحَاسࣱ فَلَا تَنتَصِرَانِ
#
# 36. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 37. فَإِذَا ٱنشَقَّتِ ٱلسَّمَاۤءُ فَكَانَتۡ وَرۡدَةࣰ كَٱلدِّهَانِ
#
# 38. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 39. فَیَوۡمَىِٕذࣲ لَّا یُسۡـَٔلُ عَن ذَنۢبِهِۦۤ إِنسࣱ وَلَا جَاۤنࣱّ
#
# 40. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 41. یُعۡرَفُ ٱلۡمُجۡرِمُونَ بِسِیمَـٰهُمۡ فَیُؤۡخَذُ بِٱلنَّوَ ٰ⁠صِی وَٱلۡأَقۡدَامِ
#
# 42. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 43. هَـٰذِهِۦ جَهَنَّمُ ٱلَّتِی یُكَذِّبُ بِهَا ٱلۡمُجۡرِمُونَ
#
# 44. یَطُوفُونَ بَیۡنَهَا وَبَیۡنَ حَمِیمٍ ءَانࣲ
#
# 45. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 46. وَلِمَنۡ خَافَ مَقَامَ رَبِّهِۦ جَنَّتَانِ
#
# 47. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 48. ذَوَاتَاۤ أَفۡنَانࣲ
#
# 49. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 50. فِیهِمَا عَیۡنَانِ تَجۡرِیَانِ
#
# 51. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 52. فِیهِمَا مِن كُلِّ فَـٰكِهَةࣲ زَوۡجَانِ
#
# 53. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 54. مُتَّكِـِٔینَ عَلَىٰ فُرُشِۭ بَطَاۤىِٕنُهَا مِنۡ إِسۡتَبۡرَقࣲۚ وَجَنَى ٱلۡجَنَّتَیۡنِ دَانࣲ
#
# 55. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 56. فِیهِنَّ قَـٰصِرَ ٰ⁠تُ ٱلطَّرۡفِ لَمۡ یَطۡمِثۡهُنَّ إِنسࣱ قَبۡلَهُمۡ وَلَا جَاۤنࣱّ
#
# 57. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 58. كَأَنَّهُنَّ ٱلۡیَاقُوتُ وَٱلۡمَرۡجَانُ
#
# 59. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 60. هَلۡ جَزَاۤءُ ٱلۡإِحۡسَـٰنِ إِلَّا ٱلۡإِحۡسَـٰنُ
#
# 61. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 62. وَمِن دُونِهِمَا جَنَّتَانِ
#
# 63. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 64. مُدۡهَاۤمَّتَانِ
#
# 65. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 66. فِیهِمَا عَیۡنَانِ نَضَّاخَتَانِ
#
# 67. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 68. فِیهِمَا فَـٰكِهَةࣱ وَنَخۡلࣱ وَرُمَّانࣱ
#
# 69. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 70. فِیهِنَّ خَیۡرَ ٰ⁠تٌ حِسَانࣱ
#
# 71. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 72. حُورࣱ مَّقۡصُورَ ٰ⁠تࣱ فِی ٱلۡخِیَامِ
#
# 73. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 74. لَمۡ یَطۡمِثۡهُنَّ إِنسࣱ قَبۡلَهُمۡ وَلَا جَاۤنࣱّ
#
# 75. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 76. مُتَّكِـِٔینَ عَلَىٰ رَفۡرَفٍ خُضۡرࣲ وَعَبۡقَرِیٍّ حِسَانࣲ
#
# 77. فَبِأَیِّ ءَالَاۤءِ رَبِّكُمَا تُكَذِّبَانِ
#
# 78. تَبَـٰرَكَ ٱسۡمُ رَبِّكَ ذِی ٱلۡجَلَـٰلِ وَٱلۡإِكۡرَامِ

# %% [markdown]
# ### Function to get translation of an Ayah

# %%
def get_translation(surah_number, ayah_number):
    response = requests.get(f"{BASE_URL}/ayah/{surah_number}:{ayah_number}/ur.maududi")
    if response.status_code == 200:
        translation = response.json()['data']['text']
        print(f"Translation: {translation}")
    else:
        print("Invalid Ayah or API error.")
# get_translation(2,286)
# Out:
# Translation: اللہ کسی متنفس پر اُس کی مقدرت سے بڑھ کر ذمہ داری کا بوجھ نہیں ڈالتا ہر شخص نے جو نیکی کمائی ہے، اس کا پھل اسی کے لیے ہے اور جو بدی سمیٹی ہے، اس کا وبال اسی پر ہے (ایمان لانے والو! تم یوں دعا کیا کرو) اے ہمارے رب! ہم سے بھول چوک میں جو قصور ہو جائیں، ان پر گرفت نہ کر مالک! ہم پر وہ بوجھ نہ ڈال، جو تو نے ہم سے پہلے لوگوں پر ڈالے تھے پروردگار! جس بار کو اٹھانے کی طاقت ہم میں نہیں ہے، وہ ہم پر نہ رکھ، ہمارے ساتھ نرمی کر، ہم سے در گزر فرما، ہم پر رحم کر، تو ہمارا مولیٰ ہے، کافروں کے مقابلے میں ہماری مدد کر

# %% [markdown]
# ### Function to play recitation of an Ayah

# %%
def play_recitation(surah_number, ayah_number):
    response = requests.get(f"{BASE_URL}/ayah/{surah_number}:{ayah_number}/ar.abdurrahmaansudais")
    if response.status_code == 200:
        audio_url = response.json()['data']['audio']
        print(f"Playing recitation: {audio_url}")
        playsound(audio_url)
    else:
        print("Error fetching recitation.")
# play_recitation(2,286)

# %% [markdown]
# ### Main menu

# %%
def main():
    while True:
        print("\nQuran Console App")
        print("1. List Surahs")
        print("2. Get Surah Ayahs")
        print("3. Get Ayah Translation")
        print("4. Listen to Ayah Recitation")
        print("5. Exit")
        choice = input("Enter your choice: ")

        if choice == "1":
            list_surahs()
        elif choice == "2":
            surah = input("Enter Surah number: ")
            get_surah(surah)
        elif choice == "3":
            surah = input("Enter Surah number: ")
            ayah = input("Enter Ayah number: ")
            get_translation(surah, ayah)
        elif choice == "4":
            surah = input("Enter Surah number: ")
            ayah = input("Enter Ayah number: ")
            play_recitation(surah, ayah)
        elif choice == "5":
            print("Exiting Quran Console App. Goodbye!")
            break
        else:
            print("Invalid choice, please try again.")

# Run the app
if __name__ == "__main__":
    main()
# Out:
# Quran Console App
# 1. List Surahs
# 2. Get Surah Ayahs
# 3. Get Ayah Translation
# 4. Listen to Ayah Recitation
# 5. Exit
# Enter your choice:  2
# Enter Surah number:  69
# 1. بِسۡمِ ٱللَّهِ ٱلرَّحۡمَـٰنِ ٱلرَّحِیمِ ٱلۡحَاۤقَّةُ
#
# 2. مَا ٱلۡحَاۤقَّةُ
#
# 3. وَمَاۤ أَدۡرَىٰكَ مَا ٱلۡحَاۤقَّةُ
#
# 4. كَذَّبَتۡ ثَمُودُ وَعَادُۢ بِٱلۡقَارِعَةِ
#
# 5. فَأَمَّا ثَمُودُ فَأُهۡلِكُوا۟ بِٱلطَّاغِیَةِ
#
# 6. وَأَمَّا عَادࣱ فَأُهۡلِكُوا۟ بِرِیحࣲ صَرۡصَرٍ عَاتِیَةࣲ
#
# 7. سَخَّرَهَا عَلَیۡهِمۡ سَبۡعَ لَیَالࣲ وَثَمَـٰنِیَةَ أَیَّامٍ حُسُومࣰاۖ فَتَرَى ٱلۡقَوۡمَ فِیهَا صَرۡعَىٰ كَأَنَّهُمۡ أَعۡجَازُ نَخۡلٍ خَاوِیَةࣲ
#
# 8. فَهَلۡ تَرَىٰ لَهُم مِّنۢ بَاقِیَةࣲ
#
# 9. وَجَاۤءَ فِرۡعَوۡنُ وَمَن قَبۡلَهُۥ وَٱلۡمُؤۡتَفِكَـٰتُ بِٱلۡخَاطِئَةِ
#
# 10. فَعَصَوۡا۟ رَسُولَ رَبِّهِمۡ فَأَخَذَهُمۡ أَخۡذَةࣰ رَّابِیَةً
#
# 11. إِنَّا لَمَّا طَغَا ٱلۡمَاۤءُ حَمَلۡنَـٰكُمۡ فِی ٱلۡجَارِیَةِ
#
# 12. لِنَجۡعَلَهَا لَكُمۡ تَذۡكِرَةࣰ وَتَعِیَهَاۤ أُذُنࣱ وَ ٰ⁠عِیَةࣱ
#
# 13. فَإِذَا نُفِخَ فِی ٱلصُّورِ نَفۡخَةࣱ وَ ٰ⁠حِدَةࣱ
#
# 14. وَحُمِلَتِ ٱلۡأَرۡضُ وَٱلۡجِبَالُ فَدُكَّتَا دَكَّةࣰ وَ ٰ⁠حِدَةࣰ
#
# 15. فَیَوۡمَىِٕذࣲ وَقَعَتِ ٱلۡوَاقِعَةُ
#
# 16. وَٱنشَقَّتِ ٱلسَّمَاۤءُ فَهِیَ یَوۡمَىِٕذࣲ وَاهِیَةࣱ
#
# 17. وَٱلۡمَلَكُ عَلَىٰۤ أَرۡجَاۤىِٕهَاۚ وَیَحۡمِلُ عَرۡشَ رَبِّكَ فَوۡقَهُمۡ یَوۡمَىِٕذࣲ ثَمَـٰنِیَةࣱ
#
# 18. یَوۡمَىِٕذࣲ تُعۡرَضُونَ لَا تَخۡفَىٰ مِنكُمۡ خَافِیَةࣱ
#
# 19. فَأَمَّا مَنۡ أُوتِیَ كِتَـٰبَهُۥ بِیَمِینِهِۦ فَیَقُولُ هَاۤؤُمُ ٱقۡرَءُوا۟ كِتَـٰبِیَهۡ
#
# 20. إِنِّی ظَنَنتُ أَنِّی مُلَـٰقٍ حِسَابِیَهۡ
#
# 21. فَهُوَ فِی عِیشَةࣲ رَّاضِیَةࣲ
#
# 22. فِی جَنَّةٍ عَالِیَةࣲ
#
# 23. قُطُوفُهَا دَانِیَةࣱ
#
# 24. كُلُوا۟ وَٱشۡرَبُوا۟ هَنِیۤـَٔۢا بِمَاۤ أَسۡلَفۡتُمۡ فِی ٱلۡأَیَّامِ ٱلۡخَالِیَةِ
#
# 25. وَأَمَّا مَنۡ أُوتِیَ كِتَـٰبَهُۥ بِشِمَالِهِۦ فَیَقُولُ یَـٰلَیۡتَنِی لَمۡ أُوتَ كِتَـٰبِیَهۡ
#
# 26. وَلَمۡ أَدۡرِ مَا حِسَابِیَهۡ
#
# 27. یَـٰلَیۡتَهَا كَانَتِ ٱلۡقَاضِیَةَ
#
# 28. مَاۤ أَغۡنَىٰ عَنِّی مَالِیَهۡۜ
#
# 29. هَلَكَ عَنِّی سُلۡطَـٰنِیَهۡ
#
# 30. خُذُوهُ فَغُلُّوهُ
#
# 31. ثُمَّ ٱلۡجَحِیمَ صَلُّوهُ
#
# 32. ثُمَّ فِی سِلۡسِلَةࣲ ذَرۡعُهَا سَبۡعُونَ ذِرَاعࣰا فَٱسۡلُكُوهُ
#
# 33. إِنَّهُۥ كَانَ لَا یُؤۡمِنُ بِٱللَّهِ ٱلۡعَظِیمِ
#
# 34. وَلَا یَحُضُّ عَلَىٰ طَعَامِ ٱلۡمِسۡكِینِ
#
# 35. فَلَیۡسَ لَهُ ٱلۡیَوۡمَ هَـٰهُنَا حَمِیمࣱ
#
# 36. وَلَا طَعَامٌ إِلَّا مِنۡ غِسۡلِینࣲ
#
# 37. لَّا یَأۡكُلُهُۥۤ إِلَّا ٱلۡخَـٰطِـُٔونَ
#
# 38. فَلَاۤ أُقۡسِمُ بِمَا تُبۡصِرُونَ
#
# 39. وَمَا لَا تُبۡصِرُونَ
#
# 40. إِنَّهُۥ لَقَوۡلُ رَسُولࣲ كَرِیمࣲ
#
# 41. وَمَا هُوَ بِقَوۡلِ شَاعِرࣲۚ قَلِیلࣰا مَّا تُؤۡمِنُونَ
#
# 42. وَلَا بِقَوۡلِ كَاهِنࣲۚ قَلِیلࣰا مَّا تَذَكَّرُونَ
#
# 43. تَنزِیلࣱ مِّن رَّبِّ ٱلۡعَـٰلَمِینَ
#
# 44. وَلَوۡ تَقَوَّلَ عَلَیۡنَا بَعۡضَ ٱلۡأَقَاوِیلِ
#
# 45. لَأَخَذۡنَا مِنۡهُ بِٱلۡیَمِینِ
#
# 46. ثُمَّ لَقَطَعۡنَا مِنۡهُ ٱلۡوَتِینَ
#
# 47. فَمَا مِنكُم مِّنۡ أَحَدٍ عَنۡهُ حَـٰجِزِینَ
#
# 48. وَإِنَّهُۥ لَتَذۡكِرَةࣱ لِّلۡمُتَّقِینَ
#
# 49. وَإِنَّا لَنَعۡلَمُ أَنَّ مِنكُم مُّكَذِّبِینَ
#
# 50. وَإِنَّهُۥ لَحَسۡرَةٌ عَلَى ٱلۡكَـٰفِرِینَ
#
# 51. وَإِنَّهُۥ لَحَقُّ ٱلۡیَقِینِ
#
# 52. فَسَبِّحۡ بِٱسۡمِ رَبِّكَ ٱلۡعَظِیمِ
#
#
# Quran Console App
# 1. List Surahs
# 2. Get Surah Ayahs
# 3. Get Ayah Translation
# 4. Listen to Ayah Recitation
# 5. Exit
# Enter your choice:  5
# Exiting Quran Console App. Goodbye!
